# %%
from kivy.interactive import InteractiveLauncher
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.graphics import Color, Ellipse


from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
# Out:
# [INFO              ] [Logger      ] Record log in C:\Users\Claudio\Anaconda3\envs\k35\.kivy\logs\kivy_16-09-04_15.txt
# [INFO              ] [Kivy        ] v1.9.1
# [INFO              ] [Python      ] v3.5.2 |Continuum Analytics, Inc.| (default, Jul  5 2016, 11:45:57) [MSC v.1900 32 bit (Intel)]
# [INFO              ] [Factory     ] 179 symbols loaded
# [INFO              ] [Image       ] Providers: img_tex, img_dds, img_gif, img_sdl2 (img_pil, img_ffpyplayer ignored)

# %%
from kivy.uix.button import Button
bt = Button(text="estudo")

# %%
class EstudoApp(App):
    def build(self):
        return Widget()

i = InteractiveLauncher( EstudoApp() )

i.run()

# %%
i.root.add_widget(bt)

# %%
bt.text = "oi"

# %%
def bt_click():
    print("eXcript")

# %%
bt.on_press = bt_click
